# %%
import pandas as pd
import requests
import time 
import datetime
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update(
    {'pdf.fonttype':42,
    'ps.fonttype': 42
})
import numpy
import re

# %%
df = pd.read_csv('bev352od3522.csv')
df.head()
# Out:
#    StichtagDatJahr  WegBezirkHistSort WegBezirkHistLang  WegKtHistSort  \
# 0             1993                101  Bezirk Affoltern              1
# 1             1993                101  Bezirk Affoltern              1
# 2             1993                101  Bezirk Affoltern              1
# 3             1993                101  Bezirk Affoltern              1
# 4             1993                101  Bezirk Affoltern              1
#
#   WegKtHistLang  WegLandHistSort WegLandHistLang  WegRegionSort  \
# 0        Zürich             8100         Schweiz             13
# 1        Zürich             8100         Schweiz             13
# 2        Zürich             8100         Schweiz             13
# 3        Zürich             8100         Schweiz             13
# 4        Zürich             8100         Schweiz             13
#
#    WegRegionLang  WegKontinentSort WegKontinentLang  QuarSort QuarLang  \
# 0  Zentraleuropa                 1           Europa        11  Rathaus
# 1  Zentraleuropa                 1           Europa        11  Rathaus
# 2  Zentraleuropa                 1           Europa        11  Rathaus
# 3  Zentraleuropa                 1           Europa        11  Rathaus
# 4  Zentraleuropa                 1           Europa        11  Rathaus
#
#    KreisSort  AlterV10Sort AlterV10Kurz SexKurz  Ziv2Sort     Ziv2Lang  \
# 0          1             1          0-9       M         1        Ledig
# 1          1             3        20-29       M         1        Ledig
# 2          1             3        20-29       W         1        Ledig
# 3          1             4        30-39       M         2  Verheiratet
# 4          1             4        30-39       W         2  Verheiratet
#
#    AnzWezuWir
# 0           2
# 1           1
# 2           1
# 3           2
# 4           1

# %%
df.groupby('StichtagDatJahr').sum()
# Out:
#                  WegBezirkHistSort  WegKtHistSort  WegLandHistSort  \
# StichtagDatJahr
# 1993                      84302250         842604        147831025
# 1994                      88568501         884833        155634602
# 1995                      89452300         893649        156538627
# 1996                      93035975         928706        160684038
# 1997                      92085764         919398        160970246
# 1998                      88758986         887405        159831959
# 1999                      84367654         844774        156116760
# 2000                      83277273         833700        157524939
# 2001                      82198282         822890        154662538
# 2002                      80616808         806943        152474235
# 2003                      78710613         788021        150187034
# 2004                      81519293         815780        156103827
# 2005                      82273145         822481        156514749
# 2006                      84248128         842163        156979624
# 2007                      88027312         879685        160024617
# 2008                      78591939         785891        152987561
# 2009                      79084285         790784        154720249
# 2010                      81568039         814953        158406518
# 2011                      81735648         816451        156521398
# 2012                      80939696         808531        155620381
# 2013                      80343139         805590        150332862
# 2014                      79867704         800538        145741201
# 2015                      80164131         803322        148409865
# 2016                      81944495         820973        149664526
# 2017                      81954807         820922        148714956
#
#                  WegRegionSort  WegKontinentSort  QuarSort  KreisSort  \
# StichtagDatJahr
# 1993                    379837             31234   1252882     120877
# 1994                    395751             32446   1317337     127060
# 1995                    399466             32770   1322357     127555
# 1996                    406533             33278   1360795     131225
# 1997                    407418             33391   1358288     131011
# 1998                    418849             34541   1349202     130110
# 1999                    407518             33651   1320815     127356
# 2000                    407024             33561   1341919     129460
# 2001                    403299             33289   1314311     126710
# 2002                    396211             32715   1310243     126411
# 2003                    388279             32017   1290673     124449
# 2004                    401722             33162   1357628     130980
# 2005                    395144             32511   1353499     130545
# 2006                    398325             32769   1352264     130386
# 2007                    412414             34052   1393588     134451
# 2008                    388264             32114   1347637     130059
# 2009                    391627             32361   1354526     130659
# 2010                    400418             33072   1383792     133444
# 2011                    397634             32917   1378173     133010
# 2012                    394495             32640   1370748     132286
# 2013                    405040             33803   1323790     127697
# 2014                    389544             32494   1290679     124481
# 2015                    390835             32491   1304177     125804
# 2016                    393749             32747   1326067     127956
# 2017                    390237             32398   1317353     127116
#
#                  AlterV10Sort  Ziv2Sort  AnzWezuWir
# StichtagDatJahr
# 1993                    70361     29107       35738
# 1994                    75461     30938       36548
# 1995                    75987     31299       36634
# 1996                    78649     32205       37269
# 1997                    79166     32370       36987
# 1998                    78507     31832       37980
# 1999                    76796     31179       38283
# 2000                    77151     31102       39859
# 2001                    75634     30363       38441
# 2002                    74564     29916       36447
# 2003                    74353     29580       36647
# 2004                    77039     30452       38588
# 2005                    77371     30818       38789
# 2006                    77383     30708       39136
# 2007                    79351     31390       40437
# 2008                    75203     30029       39475
# 2009                    76297     30085       39901
# 2010                    78070     30862       40181
# 2011                    76843     30542       39411
# 2012                    77204     30599       38479
# 2013                    74860     29605       40491
# 2014                    72186     28569       37755
# 2015                    73385     28936       38643
# 2016                    74670     29288       39038
# 2017                    74576     29048       37687

# %%
# Out:
#     AlterV10Kurz  StichtagDatJahr  AnzWezuWir
# 0            0-9             2017        1743
# 1          10-19             2017         722
# 2   100 u. älter             2017           3
# 3          20-29             2017        7048
# 4          30-39             2017        6533
# 5          40-49             2017        2654
# 6          50-59             2017        1389
# 7          60-69             2017         595
# 8          70-79             2017         206
# 9          80-89             2017          91
# 10         90-99             2017          24

# %%
df_age = pd.DataFrame()
container = pd.DataFrame()

for year in list(set(df['StichtagDatJahr'])):
    container = pd.DataFrame(df[(df['StichtagDatJahr']==year) & (df['WegLandHistLang']=='Schweiz')].groupby(['AlterV10Kurz','StichtagDatJahr'], as_index=False)['AnzWezuWir'].sum())
    df_age = pd.concat([df_age, container])

df_age.head()
# Out:
#   AlterV10Kurz  StichtagDatJahr  AnzWezuWir
# 0          0-9             1993        1433
# 1        10-19             1993         967
# 2        20-29             1993        9035
# 3        30-39             1993        4577
# 4        40-49             1993        1604

# %%
def get_percentage(row):
    percentage = row['AnzWezuWir']/df[(df['StichtagDatJahr']==row['StichtagDatJahr']) & (df['WegLandHistLang']=='Schweiz')].AnzWezuWir.sum()*100
    return pd.Series({
        'percentage': percentage
        })

# %%
df_age['percentage'] = df_age.apply(get_percentage, axis=1)
df_age.head(11)
# Out:
#   AlterV10Kurz  StichtagDatJahr  AnzWezuWir  percentage
# 0          0-9             1993        1433    7.396129
# 1        10-19             1993         967    4.990968
# 2        20-29             1993        9035   46.632258
# 3        30-39             1993        4577   23.623226
# 4        40-49             1993        1604    8.278710
# 5        50-59             1993         844    4.356129
# 6        60-69             1993         517    2.668387
# 7        70-79             1993         192    0.990968
# 8        80-89             1993         154    0.794839
# 9        90-99             1993          52    0.268387
# 0          0-9             1994        1549    7.796849

# %%
def get_agelabel(row):
    if row['AlterV10Kurz']=="0-9":
        return "0-19"
    if row['AlterV10Kurz']=="10-19":
        return "0-19"
    if row['AlterV10Kurz']=="20-29":
        return "20-29"
    if row['AlterV10Kurz']=="30-39":
        return "30-39"
    if row['AlterV10Kurz']=="40-49":
        return "40-49"
    if row['AlterV10Kurz']=="50-59":
        return "50-59"
    if row['AlterV10Kurz']=="60-69":
        return "60-69"
    if row['AlterV10Kurz']=="60-69":
        return "70+"
    if row['AlterV10Kurz']=="80-89":
        return "70+"    
    if row['AlterV10Kurz']=="90-99":
        return "70+"
    if row['AlterV10Kurz']=="100 u. älter":
        return "70+"
    else:
        return 'other'

# %%
df_age['age_label'] = df_age.apply(get_agelabel, axis=1)
df_age.grouby(age_label)
# Out:
#   AlterV10Kurz  StichtagDatJahr  AnzWezuWir  percentage age_label
# 0          0-9             1993        1433    7.396129      0-19
# 1        10-19             1993         967    4.990968      0-19
# 2        20-29             1993        9035   46.632258     20-29
# 3        30-39             1993        4577   23.623226     30-39
# 4        40-49             1993        1604    8.278710     40-49

# %%
df_age = df_age.groupby(['StichtagDatJahr', 'age_label'], as_index=False).percentage.sum()

# %%
color_dict = {
    '0-19': 'gray',
    '20-29': 'pink',
    '30-39': 'orange',
    '40-49': 'blue',
    '50-59': 'green',
    '60-69': 'purple',
    '70+': 'cyan',
    'other': "lightgrey"
}
dot_colors = [color_dict[name] for name in df_age.age_label]

ax = df_age[df_age['age_label']=="0-19"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='lightgrey', legend=False)
df_age[df_age['age_label']=="20-29"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='red', legend=False, ax=ax)
df_age[df_age['age_label']=="30-39"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='pink', legend=False, ax=ax)
df_age[df_age['age_label']=="40-49"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='lightgrey', legend=False, ax=ax)
df_age[df_age['age_label']=="50-59"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='lightgrey', legend=False, ax=ax)
df_age[df_age['age_label']=="60-69"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='lightgrey', legend=False, ax=ax)
df_age[df_age['age_label']=="70+"].plot(kind = 'line', x='StichtagDatJahr', y='percentage',  linestyle='-', color='lightgrey', legend=False, ax=ax)

# %%
df_bev = pd.read_csv('bev390od3903.csv')
df_bev.head()
# Out:
#    StichtagDatJahr  QuarSort  QuarCd QuarLang  AlterVSort  AlterVKurz  \
# 0             1993        11      11  Rathaus           0           0
# 1             1993        11      11  Rathaus           0           0
# 2             1993        11      11  Rathaus           0           0
# 3             1993        11      11  Rathaus           0           0
# 4             1993        11      11  Rathaus           1           1
#
#    AlterV05Sort AlterV05Kurz  HerkunftLang  HerkunftSort  SexCd SexKurz  \
# 0             1          0-4  Schweizer/in             1      1       M
# 1             1          0-4  Schweizer/in             1      2       W
# 2             1          0-4  Ausländer/in             2      1       M
# 3             1          0-4  Ausländer/in             2      2       W
# 4             1          0-4  Schweizer/in             1      1       M
#
#    AnzBestWir
# 0          11
# 1           8
# 2           1
# 3           6
# 4          11
