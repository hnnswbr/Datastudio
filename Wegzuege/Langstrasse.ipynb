# %% [markdown]
# # Who owns Langstrasse and profits from rising rents?
# The Langstrasse was the heart of the red light district in Zurich. In the last 20 years it has changed. Rents have gone up, buildings have been renovated – the whole neighbourhood has been gentrified. But who profits from the rising rents? Have actually companies bought buildings there? The land office of Zurich handed the current owners of the buildings to us – in PDF-format. Let's change that and find a way to analyze the data.

# %%
#import the libraries
import pandas as pd
import PyPDF2
import re

# %%
#import the AU-PDF
pdfFileObj = open('04-Langstrasse_Eig.Auskunft.pdf', 'rb')
pdfFileObj
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %% [markdown]
# #### Read in all the pages of the first PDF
# With a loop, read in all the pages and split the text at the kataster-number to get the single buildings.

# %%
data = list()
for page in list(range(0,pdfReader.numPages)):
    pageObj = pdfReader.getPage(page)
    langstrasse = pageObj.extractText()
    #print(page)
    langstrasse = langstrasse.replace("\n", "").strip()
    buildings = re.split(r", Kataster", langstrasse) #getting number of listing out
    data.append(buildings)
data[0]
# Out:
# ['- 1 - Eigentümerauskunft   Stadtquartier Zürich-Aussersihl 1.   Grundbuch Blatt 1028, Liegenschaft',
#  ' AU4987, EGRID CH607891279986, Aussersihl Eigentümer: Herr Fredy Schönholzer, geb. 08.12.1949, Bürgerort: Bürglen TG, Postfach Nr. 47, 6052 Hergiswil NW, Bibimoos, 6052 Hergiswil NW, als Alleineigentü-mer    2.   Grundbuch Blatt 966, Liegenschaft',
#  ' AU1093, EGRID CH767199918587, Aussersihl Eigentümer: Herr Bruno Paolo Caretta, geb. 29.06.1947, Bürgerort: Zürich, Hurdnerwäldli-strasse 37, 8808 Pfäffikon SZ, als Miteigentümer zu 1/3  Herr Mauro Claudio Caretta, geb. 26.02.1974, Bürgerort: Zürich, Mülibach-strasse 41, 8805 Richterswil, als Miteigentümer zu 1/3  Herr Rafael Sandro Caretta, geb. 25.06.1975, Bürgerort: Zürich, Militärstrasse 91, 8004 Zürich, als Miteigentümer zu 1/3    3.   Grundbuch Blatt 965, Liegenschaft',
#  ' AU1092, EGRID CH549199789993, Aussersihl Eigentümer: Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürgerorte: Splügen GR, Nufenen GR, im Stüdacker 19, 8902 Urdorf, als Alleineigentümer']

# %% [markdown]
# ## The Loop
# - It needs a loop within a loop (for each page and each building)
# - Leave out the first one (0) as the first page has additional info on it
# - make an empty list to fill up with the data
# - split at EGRID and afterwards at ", als"

# %%
data_AU = list()

for page in list(range(0,pdfReader.numPages)):
    for building in data[page][1:]:
        places = {
            'kataster': 0,
            'owner': 0
        }
        try: # look at the simple ones
            print(re.split(r", ",building)[0]) #Kataster Nummer
            places['kataster'] = re.split(r", ",building)[0]
            #print(re.split(r"Eigentümer: ", building)[1]) #all owners without XY.Y
            owner = re.split(r"Eigentümer: ", building)[1] #split the owners by Eiegentümer
        except:
            try: #look at the XY.Y ones | where several owner own different stories of one building
                owner = re.split(r"EGRID CH\d* (\w*[\s]*)",building)[2] #split by egrid
            except:
                print("no owner")
        try: #split the owners up, try because there is sometimes no owner
            owner = re.split(r", als", owner) #now split every cell by , als to get all the different owners
            #print(owner)
            #print(len(owner))
        except:
            print("no owner")
        new_list = list()
        if len(owner)!=0: #only save the ownes who have owners
            for i in range(0, len(owner)): #make list of range for different owners
                new_list.append(i-1)
            places['owner']=[owner[own] for own in new_list[1:]] #list comprehension to get all the owners in the dictianory
        #print(places)
        data_AU.append(places) #append to a list
# Out:
#  AU4987
#  AU1093
#  AU1092
#  AU1091
#  AU1082
#  AU1031
#  AU6035
#  AU6034
#  AU1028
#  AU1027
#  AU984
#  AU983
#  AU980
#  AU979
#  AU978
#  AU6741
#  AU6740
#  AU953
#  AU7042
#  AU914
#  AU5206
#  AU903
#  AU5444
#  AU864
#  AU863
#  AU845
#  AU836
#  AU813
#  AU812
#  AU6403
# no owner
# no owner
#  AU6403
#  AU6403
#  AU6403
#  AU6403
#  AU6403
#  AU6403
#  AU6403
#  AU6403
#  AU6403
#  AU809
#  AU804
#  AU785
#  AU784
#  AU783
#  AU782
#  AU5927
#  AU5928
#  AU6383
#  AU777
#  AU5885
#  AU766
#  AU760
#  AU759
# no owner
# no owner
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU759
#  AU871
#  AU6948
# no owner
# no owner
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU6948
#  AU5437
#  AU5443
#  AU6576
#  AU7036
#  AU7074
#  AU6578
#  AU4891
#  AU4890
#  AU1307
#  AU1306
#  AU1265
#  AU5408
#  AU1260
#  AU4818
#  AU1229
#  AU1228
#  AU1227
#  AU1165

# %% [markdown]
# Get the addresses of the owners by looking at the end of the string and doing a split.

# %%
owner_add = list()
for building in data_AU:
    owner_add = list()
    try: #Stadt Zürich and Erbgemeinschaften don't have addresses
        for i in range(0, len(building['owner'])): #make list of range for different owners
            print(i)
            print(building['kataster'])
            add = re.split(",", building['owner'][i])[-2].strip()+", "+re.split(",", building['owner'][i])[-1].strip()
            owner_add.append(add)
    except:
        if len(building['owner'])>1: #to get the addresses of the single inheritants
            for i in range(1, len(building['owner'])): #make list of range for different owners
                print(i)
                print(building['kataster'])
                add = re.split(",", building['owner'][i])[-2].strip()+", "+re.split(",", building['owner'][i])[-1].strip()
                owner_add.append(add)
        else:  
            print("no address")
            add = "no address"
        owner_add.append(add)
    building.update( {"owner_address": owner_add})
# Out:
# 0
#  AU4987
# 0
#  AU1093
# 1
#  AU1093
# 2
#  AU1093
# 0
#  AU1092
# 0
#  AU1091
# 0
#  AU1082
# 1
#  AU1082
# 0
#  AU1031
# 0
#  AU6035
# 0
#  AU6034
# 0
#  AU1028
# 0
#  AU1027
# 0
#  AU984
# 0
#  AU983
# 0
#  AU980
# 0
#  AU979
# 0
#  AU978
# 0
#  AU6741
# 0
#  AU6740
# 0
#  AU953
# 0
#  AU7042
# 1
#  AU7042
# 0
#  AU914
# 0
#  AU5206
# no address
# 0
#  AU903
# 0
#  AU5444
# 0
#  AU864
# 0
#  AU863
# 0
#  AU845
# 0
#  AU836
# 0
#  AU813
# 0
#  AU812
# 0
#  AU6403
# 0
#  AU6403
# 0
#  AU6403
# 0
#  AU6403
# 0
#  AU6403
# 0
#  AU6403
# 0
#  AU6403
# 1
#  AU6403
# 0
#  AU6403
# 1
#  AU6403
# 0
#  AU6403
# 0
#  AU6403
# 0
#  AU809
# 0
#  AU804
# 0
#  AU785
# 0
#  AU784
# 1
#  AU784
# 2
#  AU784
# 3
#  AU784
# 0
#  AU783
# 1
#  AU783
# 2
#  AU783
# 0
#  AU782
# 1
#  AU782
# 0
#  AU5927
# 0
#  AU5928
# 0
#  AU6383
# 0
#  AU777
# 0
#  AU5885
# 0
#  AU766
# 0
#  AU760
# 1
#  AU760
# 0
#  AU759
# 1
#  AU759
# 0
#  AU759
# 0
#  AU759
# 0
#  AU759
# 0
#  AU759
# 0
#  AU759
# 1
#  AU759
# 0
#  AU759
# 0
#  AU759
# 0
#  AU759
# 0
#  AU759
# 0
#  AU759
# 1
#  AU759
# 0
#  AU759
# 0
#  AU871
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 2
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 0
#  AU6948
# 1
#  AU6948
# 2
#  AU6948
# 0
#  AU5437
# no address
# 0
#  AU5443
# no address
# 0
#  AU6576
# no address
# 0
#  AU7036
# 0
#  AU7074
# 0
#  AU6578
# 0
#  AU4891
# 0
#  AU4890
# 0
#  AU1307
# 1
#  AU1307
# 2
#  AU1307
# 3
#  AU1307
# 0
#  AU1306
# 0
#  AU1265
# 0
#  AU5408
# 1
#  AU5408
# 2
#  AU5408
# 3
#  AU5408
# 0
#  AU1260
# 0
#  AU4818
# 1
#  AU4818
# 2
#  AU4818
# 0
#  AU1229
# 0
#  AU1228
# 0
#  AU1227
# 0
#  AU1165
# 1
#  AU1165

# %% [markdown]
# For the first data frame, the data has been collected. Every Kataster-Number has it's owner. It is still messy. Now put it in a Panda-DF and clean it up afterwards.

# %%
df_au = pd.DataFrame()
for owner in data_AU:
    owner_df = pd.DataFrame(owner)
    df_au=pd.concat([df_au, owner_df])
df_au.head()
# Out:
#   kataster                                              owner  \
# 0   AU4987  Herr Fredy Schönholzer, geb. 08.12.1949, Bürge...
# 0   AU1093  Herr Bruno Paolo Caretta, geb. 29.06.1947, Bür...
# 1   AU1093   Miteigentümer zu 1/3  Herr Mauro Claudio Care...
# 2   AU1093   Miteigentümer zu 1/3  Herr Rafael Sandro Care...
# 0   AU1092  Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürge...
#
#                                  owner_address
# 0                  Bibimoos, 6052 Hergiswil NW
# 0  Hurdnerwäldli-strasse 37, 8808 Pfäffikon SZ
# 1        Mülibach-strasse 41, 8805 Richterswil
# 2               Militärstrasse 91, 8004 Zürich
# 0                 im Stüdacker 19, 8902 Urdorf

# %% [markdown]
# Get the "Miteiegntümer, Gesamteigentümer" stuff out

# %%
df_au['owner_update1'] = df_au.owner.str.replace(r'.*eigentümer.*  ' , '')

# %%
df_au['owner_update1'] = df_au['owner_update1'].str.strip()

# %% [markdown]
# Save a new column with only the names of the owner.

# %%
df_au['owner_name'] = df_au['owner_update1'].str.split(',',expand=True)[0]

# %% [markdown]
# safe a new columne with the additional infos of the owner

# %%
df_au['owner_info'] = df_au['owner_update1'].str.split(',', 1,expand=True)[1]
df_au.head()
# Out:
#   kataster                                              owner  \
# 0   AU4987  Herr Fredy Schönholzer, geb. 08.12.1949, Bürge...
# 0   AU1093  Herr Bruno Paolo Caretta, geb. 29.06.1947, Bür...
# 1   AU1093   Miteigentümer zu 1/3  Herr Mauro Claudio Care...
# 2   AU1093   Miteigentümer zu 1/3  Herr Rafael Sandro Care...
# 0   AU1092  Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürge...
#
#                                  owner_address  \
# 0                  Bibimoos, 6052 Hergiswil NW
# 0  Hurdnerwäldli-strasse 37, 8808 Pfäffikon SZ
# 1        Mülibach-strasse 41, 8805 Richterswil
# 2               Militärstrasse 91, 8004 Zürich
# 0                 im Stüdacker 19, 8902 Urdorf
#
#                                        owner_update1  \
# 0  Herr Fredy Schönholzer, geb. 08.12.1949, Bürge...
# 0  Herr Bruno Paolo Caretta, geb. 29.06.1947, Bür...
# 1  Herr Mauro Claudio Caretta, geb. 26.02.1974, B...
# 2  Herr Rafael Sandro Caretta, geb. 25.06.1975, B...
# 0  Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürge...
#
#                    owner_name  \
# 0      Herr Fredy Schönholzer
# 0    Herr Bruno Paolo Caretta
# 1  Herr Mauro Claudio Caretta
# 2  Herr Rafael Sandro Caretta
# 0      Herr Alfred Hugo Trepp
#
#                                           owner_info
# 0   geb. 08.12.1949, Bürgerort: Bürglen TG, Postf...
# 0   geb. 29.06.1947, Bürgerort: Zürich, Hurdnerwä...
# 1   geb. 26.02.1974, Bürgerort: Zürich, Mülibach-...
# 2   geb. 25.06.1975, Bürgerort: Zürich, Militärst...
# 0   geb. 20.11.1943, Bürgerorte: Splügen GR, Nufe...

# %% [markdown]
# ## Read in second PDF with IQ

# %%
#import the AU-PDF
pdfFileObj = open('05-Langstrasse_Eig.Auskunft.pdf', 'rb')
pdfFileObj
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
data = list()
for page in list(range(0,pdfReader.numPages)):
    pageObj = pdfReader.getPage(page)
    langstrasse = pageObj.extractText()
    #print(page)
    langstrasse = langstrasse.replace("\n", "").strip()
    buildings = re.split(r", Kataster", langstrasse) #getting number of listing out
    data.append(buildings)

# %% [markdown]
# ### Repeat the steps from above
# First: the loop to get everything out

# %%
data_IQ = list()

for page in list(range(0,pdfReader.numPages)):
    for building in data[page][1:]:
        places = {
            'kataster': 0,
            'owner': 0
        }
        try: # look at the simple ones
            print(re.split(r", ",building)[0]) #Kataster Nummer
            places['kataster'] = re.split(r", ",building)[0]
            #print(re.split(r"Eigentümer: ", building)[1]) #all owners without XY.Y
            owner = re.split(r"Eigentümer: ", building)[1] #split the owners by Eiegentümer
        except:
            try: #look at the XY.Y ones
                owner = re.split(r"EGRID CH\d* (\w*[\s]*)",building)[2] #split by egrid
            except:
                print("no owner")
        try: #split the owners up, try because there is sometimes no owner
            owner = re.split(r", als", owner) #now split every cell by , als to get all the different owners
            #print(owner)
            #print(len(owner))
        except:
            print("no owner")
        new_list = list()
        if len(owner)!=0: #only save the ownes who have owners
            for i in range(0, len(owner)): #make list of range for different owners
                new_list.append(i-1)
            places['owner']=[owner[own] for own in new_list[1:]] #list comprehension to get all the owners in the dictianory
        #print(places)
        data_IQ.append(places) #append to a list
# Out:
#  IQ2303
#  IQ2245
#  IQ2243
#  IQ2213
#  IQ2166
#  IQ2281
#  IQ2142
#  IQ2138
#  IQ2316
#  IQ2167
#  IQ2282
#  IQ2244
#  IQ5720
#  IQ4000
#  IQ2328
#  IQ2168
#  IQ2280
#  IQ4118
#  IQ6639
#  IQ5719
#  IQ6732
#  IQ2165
#  IQ2178
#  IQ2176
#  IQ5327
#  IQ4398
#  IQ2318
#  IQ2175
#  IQ2177

# %% [markdown]
# get the owners address

# %%
owner_add = list()
for building in data_IQ:
    owner_add = list()
    try: #Stadt Zürich and Erbgemeinschaften don't have addresses
        for i in range(0, len(building['owner'])): #make list of range for different owners
            print(i)
            print(building['kataster'])
            add = re.split(",", building['owner'][i])[-2].strip()+", "+re.split(",", building['owner'][i])[-1].strip()
            owner_add.append(add)
    except:
        if len(building['owner'])>1: #to get the addresses of the single inheritants
            for i in range(1, len(building['owner'])): #make list of range for different owners
                print(i)
                print(building['kataster'])
                add = re.split(",", building['owner'][i])[-2].strip()+", "+re.split(",", building['owner'][i])[-1].strip()
                owner_add.append(add)
        else:  
            print("no address")
            add = "no address"
        owner_add.append(add)
    building.update( {"owner_address": owner_add})
# Out:
# 0
#  IQ2303
# 0
#  IQ2245
# 0
#  IQ2243
# 0
#  IQ2213
# no address
# 0
#  IQ2166
# 0
#  IQ2281
# 0
#  IQ2142
# 1
#  IQ2142
# 0
#  IQ2138
# 0
#  IQ2316
# 0
#  IQ2167
# 0
#  IQ2282
# 0
#  IQ2244
# 0
#  IQ5720
# 0
#  IQ4000
# 0
#  IQ2328
# 1
#  IQ2328
# 2
#  IQ2328
# 3
#  IQ2328
# 4
#  IQ2328
# 0
#  IQ2168
# 1
#  IQ2168
# 2
#  IQ2168
# 3
#  IQ2168
# 4
#  IQ2168
# 0
#  IQ2280
# 0
#  IQ4118
# 0
#  IQ6639
# 0
#  IQ5719
# 0
#  IQ6732
# 0
#  IQ2165
# 0
#  IQ2178
# 0
#  IQ2176
# 0
#  IQ5327
# 0
#  IQ4398
# 0
#  IQ2318
# 0
#  IQ2175
# 0
#  IQ2177
# 1
#  IQ2177
# 2
#  IQ2177

# %% [markdown]
# make a dataframe

# %%
df_iq = pd.DataFrame()
for owner in data_IQ:
    owner_df = pd.DataFrame(owner)
    df_iq =pd.concat([df_iq, owner_df])
df_iq.head()
# Out:
#   kataster                                              owner  \
# 0   IQ2303  Herr Konrad Schwarz, geb. 10.12.1972, Bürgeror...
# 0   IQ2245  Herr Mario Del Cimmuto, geb. 01.01.1956, Staat...
# 0   IQ2243  Herr Heinz Kurt Sönning-John, geb. 10.01.1959,...
# 0   IQ2213                                       Stadt Zürich
# 0   IQ2166  Frau Dr. iur. Leana Maria Isler, geb. 01.06.19...
#
#                         owner_address
# 0  Feldblumenstrasse 19a, 8048 Zürich
# 0       Wies-lergasse 24, 8049 Zürich
# 0   Stümelweg 7, 8914 Aeugst am Albis
# 0                          no address
# 0        Langstrasse 195, 8005 Zürich

# %%
df_iq['owner_update1'] = df_iq.owner.str.replace(r'.*eigentümer.*  ' , '')

# %%
df_iq['owner_update1'] = df_iq['owner_update1'].str.strip()

# %%
df_iq['owner_name'] = df_iq['owner_update1'].str.split(',',expand=True)[0]

# %%
df_iq['owner_info'] = df_iq['owner_update1'].str.split(',', 1,expand=True)[1]

# %% [markdown]
# ### combine the IQ and the AU dataframes to one

# %%
df_pdfs=pd.concat([df_au, df_iq])

# %%
df_pdfs.head()
# Out:
#   kataster                                              owner  \
# 0   AU4987  Herr Fredy Schönholzer, geb. 08.12.1949, Bürge...
# 0   AU1093  Herr Bruno Paolo Caretta, geb. 29.06.1947, Bür...
# 1   AU1093   Miteigentümer zu 1/3  Herr Mauro Claudio Care...
# 2   AU1093   Miteigentümer zu 1/3  Herr Rafael Sandro Care...
# 0   AU1092  Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürge...
#
#                                  owner_address  \
# 0                  Bibimoos, 6052 Hergiswil NW
# 0  Hurdnerwäldli-strasse 37, 8808 Pfäffikon SZ
# 1        Mülibach-strasse 41, 8805 Richterswil
# 2               Militärstrasse 91, 8004 Zürich
# 0                 im Stüdacker 19, 8902 Urdorf
#
#                                        owner_update1  \
# 0  Herr Fredy Schönholzer, geb. 08.12.1949, Bürge...
# 0  Herr Bruno Paolo Caretta, geb. 29.06.1947, Bür...
# 1  Herr Mauro Claudio Caretta, geb. 26.02.1974, B...
# 2  Herr Rafael Sandro Caretta, geb. 25.06.1975, B...
# 0  Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürge...
#
#                    owner_name  \
# 0      Herr Fredy Schönholzer
# 0    Herr Bruno Paolo Caretta
# 1  Herr Mauro Claudio Caretta
# 2  Herr Rafael Sandro Caretta
# 0      Herr Alfred Hugo Trepp
#
#                                           owner_info
# 0   geb. 08.12.1949, Bürgerort: Bürglen TG, Postf...
# 0   geb. 29.06.1947, Bürgerort: Zürich, Hurdnerwä...
# 1   geb. 26.02.1974, Bürgerort: Zürich, Mülibach-...
# 2   geb. 25.06.1975, Bürgerort: Zürich, Militärst...
# 0   geb. 20.11.1943, Bürgerorte: Splügen GR, Nufe...

# %% [markdown]
# ## Read in new Data to fit Kataster-Nr to an actual address
# Source OGD Zurich: http://geoservices.zh.ch/geoshopapi/v1/orders/2d821c17fb3a4213af98ece777124adb/download

# %%
address = pd.read_csv('allzurich.csv')
address.head() #PARZ_NR is equal to the id in the data before
address = address[address['STRASSENNAME']=="Langstrasse"]

# %%
address=address.rename(columns = {'PARZ_NR':'kataster'})

# %%
df_pdfs['kataster'] = df_pdfs['kataster'].astype(str).str.strip()
address['kataster'] = address['kataster'].astype(str)
address.head()
# Out:
#       BFSNR  ONRP   PLZ  ZUSATZZIFFERN ORTSCHAFTSNAME  KANTON STRASSENNAME  \
# 2792    261   NaN  8004              0         Zürich     NaN  Langstrasse
# 2793    261   NaN  8004              0         Zürich     NaN  Langstrasse
# 2938    261   NaN  8004              0         Zürich     NaN  Langstrasse
# 2944    261   NaN  8004              0         Zürich     NaN  Langstrasse
# 3107    261   NaN  8004              0         Zürich     NaN  Langstrasse
#
#      HAUSNUMMER        GEOMY        GEOMX STATUS  STATUS_GP kataster  \
# 2792         29  1247762.751  2682036.843      R        NaN    AU871
# 2793         30  1247754.775  2682059.592      R        NaN   AU5206
# 2938         81  1247997.687  2682145.875      R        NaN   AU1165
# 2944        113  1248149.039  2682204.337      R        NaN   AU5408
# 3107        118  1248161.862  2682235.118      R        NaN   AU1028
#
#         GVZ_NR   GWR_EGID  GWR_EDID            GEBAEUDEART      QUELLE  \
# 2792  26401625     148873         1  Gebaeude.Wohngebaeude  AV_2018.05
# 2793  26400508  302004639         0    Gebaeude.Verwaltung  AV_2018.05
# 2938  26401807     148748         0  Gebaeude.Wohngebaeude  AV_2018.05
# 2944  26400972    2366101         0    Gebaeude.Verwaltung  AV_2018.05
# 3107  26401623     149327         0  Gebaeude.Wohngebaeude  AV_2018.05
#
#                 E            N
# 2792  2682036.843  1247762.751
# 2793  2682059.592  1247754.775
# 2938  2682145.875  1247997.687
# 2944  2682204.337  1248149.039
# 3107  2682235.118  1248161.862

# %%
new_df = pd.merge(df_pdfs, address, on='kataster')
new_df
# Out:
#     kataster                                              owner  \
# 0     AU4987  Herr Fredy Schönholzer, geb. 08.12.1949, Bürge...
# 1     AU1093  Herr Bruno Paolo Caretta, geb. 29.06.1947, Bür...
# 2     AU1093   Miteigentümer zu 1/3  Herr Mauro Claudio Care...
# 3     AU1093   Miteigentümer zu 1/3  Herr Rafael Sandro Care...
# 4     AU1092  Herr Alfred Hugo Trepp, geb. 20.11.1943, Bürge...
# 5     AU1091  ZH Immobilien AG, mit Sitz in Zürich, CHE-113....
# 6     AU1082  Herr lic. phil. Roger Daniel Geissmann, geb. 0...
# 7     AU1082   Miteigentümer zu 1/2  Herr Paul Joseph Thoma,...
# 8     AU1031  Herr Urs Peter Humm, geb. 12.10.1942, Bürgeror...
# 9     AU6035  Herr Daniel Reitzer, geb. 29.06.1962, Bürgeror...
# 10    AU6034  Continental Film Partners AG, mit Sitz in Züri...
# 11    AU1028  Herr Urs Peter Humm, geb. 12.10.1942, Bürgeror...
#
# 214   IQ2177   Miteigentümer zu 53/100  Herr Beyhan YELOCAGI...
# 215   IQ2177   Miteigentümer zu 2/100  Herr Ayhan YELOCAGI-T...
#
#                                    owner_address  \
# 0                    Bibimoos, 6052 Hergiswil NW
# 1    Hurdnerwäldli-strasse 37, 8808 Pfäffikon SZ
# 2          Mülibach-strasse 41, 8805 Richterswil
# 3                 Militärstrasse 91, 8004 Zürich
# 4                   im Stüdacker 19, 8902 Urdorf
# 5                Krönleinstrasse 27, 8044 Zürich
# 6                   Langstrasse 132, 8004 Zürich
# 7          Oberfeld-ring 13, 8905 Arni-Islisberg
# 8                   Pilgerweg 5, 8803 Rüschlikon
# 9         Lütten-bergstrasse 17, 8906 Bonstetten
# 10             Wein-bergstrasse 166, 8006 Zürich
# 11                  Pilgerweg 5, 8803 Rüschlikon
# 12                  Pilgerweg 5, 8803 Rüschlikon
# 13                    Neuwis 4, 8700 Küsnacht ZH
# 14                    Neuwis 4, 8700 Küsnacht ZH
# 15                 Neptunstrasse 12, 8032 Zürich
# 16                  Langstrasse 108, 8004 Zürich
# 17                   Neu-wis 4, 8700 Küsnacht ZH
# 18                   Oken-strasse 6, 8037 Zürich
# 19                Im Lätten 9, 8802 Kilchberg ZH
# 20                   Langstrasse 69, 8004 Zürich
# 21           Im Cholächer 18, 8907 Wettswil a.A.
# 22         Brandschenkestrasse 152c, 8002 Zürich
# 23            Susen-bergstrasse 122, 8044 Zürich
# 24            Susen-bergstrasse 122, 8044 Zürich
# 25                                    no address
# 26                                    no address
# 27                                    no address
# 28                                    no address
# 29            Kilchberg-strasse 122, 8038 Zürich
# ..                                           ...
# 186                      1070 Bruxelles, Belgien
# 187                      1070 Bruxelles, Belgien
# 188                 Werdstrasse 113, 8004 Zürich
# 189                 Werdstrasse 113, 8004 Zürich
# 190                 Voltastrasse 32, 8044 Zürich
# 191                 Voltastrasse 32, 8044 Zürich
# 192           St. Johannsvorstadt 42, 4056 Basel
# 193           St. Johannsvorstadt 42, 4056 Basel
# 194           St. Johannsvorstadt 42, 4056 Basel
# 195           St. Johannsvorstadt 42, 4056 Basel
# 196            Stettbachstrasse 165, 8051 Zürich
# 197  Alte Schaffhausenstrasse 2, 8413 Neftenbach
# 198            Ruebisbachstrasse 74, 8302 Kloten
# 199          Schürweidstrasse 37, 8912 Obfel-den
# 200          Schürweidstrasse 37, 8912 Obfel-den
# 201                     Wartauweg 9, 8049 Zürich
# 202                     Neugasse 56, 8005 Zürich
# 203                  Oken-strasse 6, 8037 Zürich
# 204                     Pünten 5, 8602 Wangen ZH
# 205                    Sihlquai 255, 8005 Zürich
# 206                 Waserstrasse 44, 8053 Zürich
# 207                   Okenstrasse 6, 8037 Zürich
# 208                  Weststrasse 49, 8003 Zürich
# 209          Schwertstrasse 6, 8200 Schaffhausen
# 210         Waldrü-tistrasse 11, 8954 Geroldswil
# 211         Waldrü-tistrasse 11, 8954 Geroldswil
# 212         Goldbrun-nenstrasse 117, 8055 Zürich
# 213         Tala-ckerstrasse 63, 8152 Glattbrugg
# 214         Schaffhauserstrasse 459, 8052 Zürich
# 195   geb. 26.09.1976, Bürgerorte: Zürich, Aarau AG...    261   NaN  8005
# 196                                               None    261   NaN  8005
# 197   geb. 24.10.1952, Bürgeror-te: Zürich, Reinach...    261   NaN  8005
# 198   geb. 23.08.1969, Bürgerort: Oberuzwil-Niederg...    261   NaN  8005
# 199   geb. 26.05.1929, Bürgerort: Oberuzwil SG, Rue...    261   NaN  8005
# 200   geb. 17.09.1954, Bürgerorte: Su-miswald BE, O...    261   NaN  8005
# 201   geb. 30.04.1940, Bürgerorte: Zürich, Nä-fels ...    261   NaN  8005
# 202   geb. 01.03.1946, Bürgerort: Lenk, Neugasse 56...    261   NaN  8005
# 203   mit Sitz in Zürich, CHE-439.886.699, Oken-str...    261   NaN  8005
# 204   mit Sitz in Wangen-Brüttisellen, CHE-102.168....    261   NaN  8005
# 205   mit Sitz in Zürich, CHE-107.825.858, Postfach...    261   NaN  8005
# 206   geb. 12.01.1959, Bürgerort: Engi GL, Waserstr...    261   NaN  8005
# 207   mit Sitz in Zürich, CHE-352.797.407, Okenstra...    261   NaN  8005
# 208   geb. 19.08.1942, Bürgerort: Zürich, Weststras...    261   NaN  8005
# 209   öffentlich-rechtliche Anstalt, mit Sitz in Sc...    261   NaN  8005
# 210   geb. 04.11.1939, Bürgerort: Zürich, Waldrü-ti...    261   NaN  8005
# 211   geb. 04.11.1939, Bürgerort: Zürich, Waldrü-ti...    261   NaN  8005
# 212   geb. 12.12.1978, Bürgerort: Zürich, Goldbrun-...    261   NaN  8005
# 213   geb. 29.09.1981, Bürgerort: Opfikon ZH, Tala-...    261   NaN  8005
# 214   geb. 10.10.1977, Staatsangehörigkeit: Türkei,...    261   NaN  8005
# 215   geb. 11.01.1974, Bürgerort: Opfikon ZH, Gewer...    261   NaN  8005
#
#      ZUSATZZIFFERN     ...             GEOMX  STATUS STATUS_GP    GVZ_NR  \
# 0                0     ...       2682151.119       R       NaN  26402536
# 1                0     ...       2682269.710       R       NaN  26400948
# 2                0     ...       2682269.710       R       NaN  26400948
# 3                0     ...       2682269.710       R       NaN  26400948
# 4                0     ...       2682266.294       R       NaN  26400968
# 5                0     ...       2682262.755       R       NaN  26401802
# 6                0     ...       2682258.415       R       NaN  26401875
# 7                0     ...       2682258.415       R       NaN  26401875
# 8                0     ...       2682248.811       R       NaN  26401000
# 9                0     ...       2682242.959       R       NaN  26401013
# 10               0     ...       2682237.638       R       NaN  26401624
# 11               0     ...       2682235.118       R       NaN  26401623
# 12               0     ...       2682232.066       R       NaN  26401577
# 13               0     ...       2682239.804       R       NaN  26402209
# 14               0     ...       2682235.901       R       NaN      n.n.
# 15               0     ...       2682219.446       R       NaN  26401697
# 16               0     ...       2682218.614       R       NaN  26401696
# 17               0     ...       2682210.970       R       NaN  26401853
# 18               0     ...       2682204.895       R       NaN  26400514
# 19               0     ...       2682188.469       R       NaN  26400847
# 20               0     ...       2682184.345       R       NaN  26401415
# 21               0     ...       2682173.197       R       NaN  26405093
# 22               0     ...       2682173.197       R       NaN  26405093
# 23               0     ...       2682178.391       R       NaN  26400643
# 24               0     ...       2682166.483       R       NaN  26400668
# 25               0     ...       2682059.592       R       NaN  26400508
# 26               0     ...       2682079.170       R       NaN  26400360
# 27               0     ...       2682093.813       R       NaN  26404955
# 28               0     ...       2682085.974       R       NaN  26403451
# 29               0     ...       2682128.455       R       NaN  26400160
# ..             ...     ...               ...     ...       ...       ...
# 186              0     ...       2682480.664       R       NaN  28300825
# 187              0     ...       2682473.413       R       NaN  28300825
# 188              0     ...       2682480.664       R       NaN  28300825
# 189              0     ...       2682473.413       R       NaN  28300825
# 190              0     ...       2682480.664       R       NaN  28300825
# 191              0     ...       2682473.413       R       NaN  28300825
# 192              0     ...       2682480.664       R       NaN  28300825
# 193              0     ...       2682473.413       R       NaN  28300825
# 194              0     ...       2682480.664       R       NaN  28300825
# 195              0     ...       2682473.413       R       NaN  28300825
# 196              0     ...       2682359.696       R       NaN  28303371
# 197              0     ...       2682359.696       R       NaN  28303371
# 198              0     ...       2682359.696       R       NaN  28303371
# 199              0     ...       2682359.696       R       NaN  28303371
# 200              0     ...       2682359.696       R       NaN  28303371
# 201              0     ...       2682459.122       R       NaN  28301966
# 202              0     ...       2682383.258       R       NaN      n.n.
# 203              0     ...       2682404.062       R       NaN  28304305
# 204              0     ...       2682419.009       R       NaN  28300797
# 205              0     ...       2682382.167       R       NaN  28304905
# 206              0     ...       2682378.902       R       NaN  28303374
# 207              0     ...       2682417.692       R       NaN  28300983
# 208              0     ...       2682434.425       R       NaN  28302091
# 209              0     ...       2682465.136       R       NaN  28301967
# 210              0     ...       2682492.947       R       NaN  28301891
# 211              0     ...       2682483.206       R       NaN  28300690
# 212              0     ...       2682441.146       R       NaN  28301944
# 213              0     ...       2682428.349       R       NaN  28302090
# 214              0     ...       2682428.349       R       NaN  28302090
# 215              0     ...       2682428.349       R       NaN  28302090
#
#       GWR_EGID  GWR_EDID                 GEBAEUDEART      QUELLE            E  \
# 0      9011685         1       Gebaeude.Wohngebaeude  AV_2018.05  2682151.119
# 1       149349         0       Gebaeude.Wohngebaeude  AV_2018.05  2682269.710
# 2       149349         0       Gebaeude.Wohngebaeude  AV_2018.05  2682269.710
# 3       149349         0       Gebaeude.Wohngebaeude  AV_2018.05  2682269.710
# 4       149331         0         Gebaeude.Verwaltung  AV_2018.05  2682266.294
# 5       149330         0       Gebaeude.Wohngebaeude  AV_2018.05  2682262.755
# 6       149329         0       Gebaeude.Wohngebaeude  AV_2018.05  2682258.415
# 7       149329         0       Gebaeude.Wohngebaeude  AV_2018.05  2682258.415
# 8       149328         0       Gebaeude.Wohngebaeude  AV_2018.05  2682248.811
# 9      2366112         0         Gebaeude.Verwaltung  AV_2018.05  2682242.959
# 10     2366211         0         Gebaeude.Verwaltung  AV_2018.05  2682237.638
# 11      149327         0       Gebaeude.Wohngebaeude  AV_2018.05  2682235.118
# 12      149326         0       Gebaeude.Wohngebaeude  AV_2018.05  2682232.066
# 13      149270         0       Gebaeude.Wohngebaeude  AV_2018.05  2682239.804
# 14   302020843         0      Gebaeude.Nebengebaeude  AV_2018.05  2682235.901
# 15      149272         0       Gebaeude.Wohngebaeude  AV_2018.05  2682219.446
# 212     150519         0       Gebaeude.Wohngebaeude  AV_2018.05  2682441.146
# 213     150517         0        Gebaeude.Gastgewerbe  AV_2018.05  2682428.349
# 214     150517         0        Gebaeude.Gastgewerbe  AV_2018.05  2682428.349
# 215     150517         0        Gebaeude.Gastgewerbe  AV_2018.05  2682428.349
#
#                N
# 0    1248010.696
# 1    1248255.859
# 2    1248255.859
# 3    1248255.859
# 4    1248245.247
# 5    1248234.215
# 6    1248221.895
# 7    1248221.895
# 8    1248196.330
# 9    1248184.290
# 10   1248169.394
# 11   1248161.862
# 12   1248153.686
# 13   1248103.288
# 14   1248114.076
# 15   1248125.674
# 16   1248117.484
# 17   1248104.302
# 18   1248051.220
# 19   1248045.715
# 20   1248036.432
# 21   1248008.557
# 22   1248008.557
# 23   1247978.047
# 24   1247988.418
# 25   1247754.775
# 26   1247779.212
# 27   1247784.982
# 28   1247798.512
# 29   1247891.045
# ..           ...
# 186  1248658.995
# 187  1248658.572
# 188  1248658.995
# 189  1248658.572
# 190  1248658.995
# 191  1248658.572
# 192  1248658.995
# 193  1248658.572
# 194  1248658.995
# 195  1248658.572
# 196  1248503.899
# 197  1248503.899
# 198  1248503.899
# 199  1248503.899
# 200  1248503.899
# 201  1248679.936
# 202  1248595.248
# 203  1248580.339
# 204  1248607.164
# 205  1248494.104
# 206  1248539.237
# 207  1248558.079
# 208  1248587.703
# 209  1248689.811
# 210  1248743.468
# 211  1248676.601
# 212  1248600.219
# 213  1248576.251
# 214  1248576.251
# 215  1248576.251
#
# [216 rows x 25 columns]

# %% [markdown]
# Are the buildings mostly owned by companies or not?

# %%
new_df['company'] = new_df['owner_name'].str.contains('|'.join(["Herr", "Frau", "Erben", "Stadt Zürich"])) != True

# %%
company = new_df.company.value_counts('normalize')*100
print(round(company[1], 2), "Percent of the buildings on Langstrasse are owned by companies.")
# Out:
# 17.59 Percent of the buildings on Langstrasse are owned by companies.

# %% [markdown]
# #### are there people who own several buildings? Is there a Misses or a Mister Langstrasse? Or a company that owns a lot?

# %%
new_df.owner_name.value_counts().head()
# Out:
# Stadt Zürich                    8
# Herr Fredy Schönholzer          4
# Herr Urs Peter Humm             3
# Herr Morrandas NEVES BOMFIM     3
# AM und Partner Immobilien AG    3
# Name: owner_name, dtype: int64

# %% [markdown]
# -save the data to a csv

# %%
new_df.to_csv("langstrasse.csv", index=False)

# %% [markdown]
# # Get the Median Income Data
# - Using the official API of the Department of Statistics
# - Getting the most acutal ones, as they are based on tax-data, there is a four year time lag.

# %%
import requests
import time 
import datetime

# %% [markdown]
# getting the first 100 Results

# %%
url = "https://data.stadt-zuerich.ch/api/3/action/datastore_search?resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac"
response = requests.get(url)
data = response.json()

# %%
data['result'].keys()
# Out:
# dict_keys(['include_total', 'resource_id', 'fields', 'records_format', 'records', '_links', 'total'])

# %%
income_data = data['result']['records']

# %%
df_income = pd.DataFrame(income_data)
df_income.head()
# Out:
#       QuarLang QuarSort SteuerEInkommen_p50 SteuerEinkommen_p25  \
# 0      Rathaus       11                38.9               18.35
# 1      Rathaus       11                80.4                48.4
# 2      Rathaus       11                  43               23.55
# 3  Hochschulen       12                  31                12.4
# 4  Hochschulen       12               86.35                51.7
#
#   SteuerEinkommen_p75 SteuerJahr         SteuerTarifLang SteuerTarifSort  _id
# 0                64.5       1999              Grundtarif               0    1
# 1               127.7       1999      Verheiratetentarif               1    2
# 2                81.1       1999  Einelternfamilientarif               2    3
# 3                55.2       1999              Grundtarif               0    4
# 4              176.95       1999      Verheiratetentarif               1    5

# %% [markdown]
# getting the rest from the api using a while-loop to click next.

# %%
url = "https://data.stadt-zuerich.ch"
total_results = data['result']['total']
offset = int(re.findall(r"offset=(\d*)&",data['result']['_links']['next'])[0])


while offset < total_results:
    print(data['result']['_links']['next'])
    offset = int(re.findall(r"offset=(\d*)&",data['result']['_links']['next'])[0])
    response = requests.get(url+data['result']['_links']['next'])
    data = response.json()
    api_results = pd.DataFrame(data['result']['records'])
    df_income = pd.concat([df_income, api_results])
# Out:
# /api/3/action/datastore_search?offset=100&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=200&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=300&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=400&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=500&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=600&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=700&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=800&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=900&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1000&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1100&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1200&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1300&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1400&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1500&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac
# /api/3/action/datastore_search?offset=1600&resource_id=9720e2cc-6a34-452c-8f20-4fc78c9496ac

# %% [markdown]
# now filter to get only single taxed people (most of them).

# %%
df = df_income[df_income['SteuerTarifLang'] == "Grundtarif"]

# %%
#droping unused columns
df = df.drop(['SteuerEinkommen_p25', 'SteuerEinkommen_p75','SteuerTarifSort','_id'], axis=1)

# %% [markdown]
# Writing a function to see the change of the median income between 1999 and 2013.

# %%
def get_change(row):
    income_change = (float(row['SteuerEInkommen_p50'])/float(df.SteuerEInkommen_p50[(df['QuarLang']==row['QuarLang']) & (df['SteuerJahr']=='1999')])*100)-100
    return pd.Series({
        'income_change': income_change
        })

# %%
df['income_change'] = df.apply(get_change, axis=1)
df = df.sort_values(by=['income_change'], ascending=False)
df_recent = df[df['SteuerJahr']=="2013"]
df_recent.to_csv('income_change.csv', index=False)
df_recent.head(5)
# Out:
#         QuarLang QuarSort SteuerEInkommen_p50 SteuerJahr SteuerTarifLang  \
# 70   Escher Wyss       52                  60       2013      Grundtarif
# 91       Seefeld       81                  60       2013      Grundtarif
# 58          Werd       41                46.7       2013      Grundtarif
# 61   Langstrasse       42                40.5       2013      Grundtarif
# 49  Alt-Wiedikon       31                  50       2013      Grundtarif
#
#     income_change
# 70      69.014085
# 91      42.857143
# 58      40.662651
# 61      38.461538
# 49      36.986301

# %% [markdown]
# In the Langstrasse neighbourhood median income has gone up by almost 40 percent during the last 15 years.

# %% [markdown]
# ##### Now attach this info to the langstrasse df
# I have to import the data as I attached the neighbourhood-id via QGIS.

# %%
df_langstrasse = pd.read_csv("langstrasse_with_zones.csv")

# %%
#attach a building count

# %%
def get_buildings_count(row):
    count = len(df_langstrasse[df_langstrasse['owner_name']==row['owner_name']])
    return pd.Series({
        'count': count
        })

# %%
df_langstrasse['count'] = df_langstrasse.apply(get_buildings_count, axis=1)

# %%
#change colname before merge
df_recent=df_recent.rename(columns = {'QuarLang':'qname_min'})

# %%
df = pd.merge(df_langstrasse, df_recent, on='qname_min')

# %%
#get list of al colnames to
#erase the cols you are interested in
colnames = list(df.columns.values)
interested_cols = ['kataster','owner_address','owner_name','owner_info','PLZ','GEOMY','STRASSENNAME',
 'HAUSNUMMER','GEOMX','qname_min','kname_min','SteuerEInkommen_p50','SteuerJahr','SteuerTarifLang','income_change','company','count']
[colnames.remove(col) for col in interested_cols]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#drop the rest
df_small = df.drop(colnames, axis=1)
df_small.company.replace(False, "No Company", inplace=True)
df_small.company.replace(True, "Company", inplace=True)

# %%
df_small.to_csv("df_small.csv", index=False)

# %% [markdown]
# 1. Open the csv in qgis.
# 2. Get long lat instead of GEOMX/GEOMY
# 3. Export from GQIS
# 4. Load new CSV and go on.

# %%
#went to qgis
longlat = pd.read_csv('long_lat_def.csv')
df_small['geometry.coordinates'] = longlat[['X', 'Y']].values.tolist()
df_small['x'] =longlat['X']
df_small['y'] =longlat['Y']
df_small['geometry.type'] = "Point"

# %% [markdown]
# ## Preparing for Leaflet
# Get the information wanted to be displayed in "properties." columns, and the coordinates in the "geometry." columns.

# %%
df_final = pd.DataFrame()
def get_all_the_names(row):
    addresse_lang = row['STRASSENNAME']+ " " + row['HAUSNUMMER']
    allenamen = df_small.owner_name[df_small['kataster']==row['kataster']].values
    alleinfos = df_small.owner_address[df_small['kataster']==row['kataster']].values
    name = str()
    owner_all = str()
    for i in range(0,len(allenamen)):
        if name != allenamen[i] + "</br>":
            name = allenamen[i] + "</br>" + name
            owner_all = owner_all + "<b>"+allenamen[i]+"</b>" + "</br>" + alleinfos[i] + "</br>" 

    everything = str("<p>" + owner_all + "</p>" +
  "<p>own(s): " + "<i>" + addresse_lang + " (" + str(row['kataster']) + ")" + "</i>" +
  "<p>" + "Buildings owned in total: " + str(row['count']) + "</p>" +
  "<p>"+"Neighborhood: "+ row['qname_min'] +"</p>" +
  "<p>"+"Change of median income since 1999: "+ str(round(row['income_change'],2))+"%"+"</p>" +
  "<p>"+ "Median income is: " + str(float(row["SteuerEInkommen_p50"])*1000) + " CHF" +"</p>")
    allenamen = name 
    if row['company']=="No Company":
        color_company =  "#3792d6"
    else:      
        color_company = "#efb475"
    return pd.Series({
        'kataster': row['kataster'],
        'xy': str(row['x'] + row['y']),
        'properties.name': addresse_lang,
        'properties.headline': allenamen,
        'properties.article': everything,
        'properties.color': color_company,
        'properties.count': row['count'],
        'geometry.coordinates': row['geometry.coordinates'],
        'geometry.type': row['geometry.type']
        })

# %% [markdown]
# Apply the function and save the final data frame as csv.

# %%
df_final = df_small.apply(get_all_the_names, axis=1).join(df_final)

# %%
df_final = df_final.drop_duplicates('xy', keep='first')
df_final.to_csv('langstrasse_Namen_Adressen.csv')

# %% [markdown]
# ### Getting the data in geojson (applying Jon's magic)
# get the dataframe in propper format for Jon's leaflet template for a Map with points. export geojson file.

# %%
import json
#transform your pandas dataframed to json
ok_json = json.loads(df_final.to_json(orient='records'))

# %%
def process_to_geojson(file):
    geo_data = {"type": "FeatureCollection", "features":[]}
    for row in file:
        this_dict = {"type": "Feature", "properties":{}, "geometry": {}}
        for key, value in row.items():
            key_names = key.split('.')
            if key_names[0] == 'geometry':
                this_dict['geometry'][key_names[1]] = value
            if str(key_names[0]) == 'properties':
                this_dict['properties'][key_names[1]] = value
        geo_data['features'].append(this_dict)
    return geo_data

# %%
#Pass the file through function
geo_format = process_to_geojson(ok_json)

# %%
#This puts in your variable name first
#Then put in the geojson object into your file
with open('geo-data.js', 'w') as outfile:
    outfile.write("infoData = ")
with open('geo-data.js', 'a') as outfile:
    json.dump(geo_format, outfile)
